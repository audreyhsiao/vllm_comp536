# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
df_CC = pd.read_parquet("hf://datasets/zai-org/CC-Bench-trajectories/train.parquet")
print("ALFRED shape:", df_CC.shape)
print(df_CC.columns)
print(df_CC.iloc[0])
# Out:
# ALFRED shape: (370, 13)
# Index(['id', 'task_id', 'trajectory', 'model_name', 'task_category',
#        'user_messages', 'assistant_messages', 'total_input_tokens',
#        'total_output_tokens', 'total_tokens', 'tool_calls', 'tool_failures',
#        'failure_rate'],
#       dtype='object')
# id                                                                     2
# task_id                                                                1
# trajectory             [{"parentUuid": null, "isSidechain": false, "u...
# model_name                                        DeepSeek-V3.1-Terminus
# task_category                                       frontend_development
# user_messages                                                          1
# assistant_messages                                                     6
# total_input_tokens                                                   497
# total_output_tokens                                                  111
# ...
